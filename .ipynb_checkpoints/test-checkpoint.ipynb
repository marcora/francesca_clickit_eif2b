# %%
library(tidyverse)
library(magrittr)
library(readxl)
#library(effsize)
#library(pwr)
#library(BayesianFirstAid)
#library(BEST)
library(lme4)
library(emmeans)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.4     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract
#
#
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack

# %%
exp1 = read_xlsx('CLICK-it_WB_cumulative_LCLs.xlsx', sheet=1)

# %%
head(exp1)
# Out:
#   Gel Genotype Sample  Treatment TAMRA BetaActin Background Experiment
# 1 1   AA       HG01112 Vehicle   81.42  9.044    0.002      Exp1
# 2 1   AA       HG01112 Vehicle   70.22  8.711    0.002      Exp1
# 3 1   AA       HG01112 Vehicle   68.05  8.363    0.002      Exp1
# 4 1   AA       HG01112 Thapsi    27.08 10.176    0.002      Exp1
# 5 1   AA       HG01112 Thapsi    30.90 10.219    0.002      Exp1
# 6 1   AA       HG01112 Thapsi    35.83  9.784    0.002      Exp1

# %%
exp2 = read_xlsx('CLICK-it_WB_cumulative_LCLs.xlsx', sheet=2)

# %%
head(exp2)
# Out:
#   Gel Genotype Sample  Treatment TAMRA  BetaActin Background Experiment
# 1 4   AA       HG01932 Vehicle   109.16 8.949     0.431      Exp2
# 2 4   AA       HG01932 Vehicle   109.00 9.232     0.431      Exp2
# 3 4   AA       HG01932 Vehicle   108.88 8.651     0.431      Exp2
# 4 4   AA       HG01932 Thapsi     45.41 8.341     0.431      Exp2
# 5 4   AA       HG01932 Thapsi     47.33 8.482     0.431      Exp2
# 6 4   AA       HG01932 Thapsi     52.55 7.780     0.431      Exp2

# %%
exp1 %<>% mutate(Experiment = "Exp1")
exp2 %<>% mutate(Experiment = "Exp2", Gel = Gel + 3)

df = rbind(exp1, exp2)

head(df)
# Out:
#   Gel Genotype Sample  Treatment TAMRA BetaActin Background Experiment
# 1 1   AA       HG01112 Vehicle   81.42  9.044    0.002      Exp1
# 2 1   AA       HG01112 Vehicle   70.22  8.711    0.002      Exp1
# 3 1   AA       HG01112 Vehicle   68.05  8.363    0.002      Exp1
# 4 1   AA       HG01112 Thapsi    27.08 10.176    0.002      Exp1
# 5 1   AA       HG01112 Thapsi    30.90 10.219    0.002      Exp1
# 6 1   AA       HG01112 Thapsi    35.83  9.784    0.002      Exp1

# %%
df %<>%
    select(Experiment, -Gel, everything()) %>%
    group_by(Experiment) %>%
    mutate(TAMRA_ = TAMRA-Background,
           BetaActin_ = BetaActin-Background,
           NormFactor = BetaActin_/max(BetaActin_),
           NormSignal = TAMRA_/NormFactor,
           Experiment = factor(Experiment, levels = c("Exp1", "Exp2")),
           Genotype = factor(Genotype, levels = c("AA", "CC", "EIF2B2")),
           Treatment = factor(Treatment, levels = c("Vehicle", "Thapsi"))) %>%
    ungroup() %>%
    group_by(Experiment, Sample, Treatment) %>%
    mutate(MeanNormSignal=mean(NormSignal)) %>%
    ungroup() %>%
    distinct(Experiment, Genotype, Sample, Treatment, MeanNormSignal) %>%
    arrange(Experiment, Genotype, Sample, Treatment)

# %%
ggplot(df, aes(x=Genotype, y=MeanNormSignal, col=Genotype)) + geom_boxplot() + facet_grid(rows=vars(Experiment), cols=vars(Treatment)) + theme_bw()
# Out:
# plot without title

# %%
modelTreatment = lmer(MeanNormSignal ~ Treatment + (1|Experiment), data = df)

# %%
modelGenotype = lmer(MeanNormSignal ~ Genotype + (1|Experiment), data = df)

# %%
modelGenotypeAndTreatment = lmer(MeanNormSignal ~ Genotype + Treatment + (1|Experiment), data = df)

# %%
plot(modelGenotypeAndTreatment)
# Out:
# plot without title

# %%
qqnorm(resid(modelGenotypeAndTreatment))
qqline(resid(modelGenotypeAndTreatment))
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
anova(modelGenotypeAndTreatment, modelGenotype)
# Out:
# refitting model(s) with ML (instead of REML)
#                           npar AIC   BIC   logLik deviance Chisq Df Pr(>Chisq)
# modelGenotype             5    234.9 239.9 -112.5 224.9       NA NA         NA
# modelGenotypeAndTreatment 6    221.7 227.7 -104.9 209.7    15.17  1 0.00009814

# %%
anova(modelGenotypeAndTreatment, modelTreatment)
# Out:
# refitting model(s) with ML (instead of REML)
#                           npar AIC   BIC   logLik deviance Chisq Df Pr(>Chisq)
# modelTreatment            4    223.9 227.9 -108.0 215.9       NA NA      NA
# modelGenotypeAndTreatment 6    221.7 227.7 -104.9 209.7    6.192  2 0.04522

# %%
emmeans(modelGenotypeAndTreatment, list(pairwise ~ Genotype + Treatment), adjust = "tukey")
# Out:
# $`emmeans of Genotype, Treatment`
#  Genotype Treatment emmean   SE   df lower.CL upper.CL
#  AA       Vehicle    175.5 30.4 2.02    45.98      305
#  CC       Vehicle    160.6 30.4 2.02    31.09      290
#  EIF2B2   Vehicle    104.8 34.7 3.30    -0.09      210
#  AA       Thapsi      81.6 30.4 2.02   -47.96      211
#  CC       Thapsi      66.7 30.4 2.02   -62.84      196
#  EIF2B2   Thapsi      10.9 34.7 3.30   -94.02      116
#
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $`pairwise differences of Genotype, Treatment`
#  1                              estimate   SE df t.ratio p.value
#  AA Vehicle - CC Vehicle            14.9 23.6 15 0.631   0.9867
#  AA Vehicle - EIF2B2 Vehicle        70.7 28.9 15 2.449   0.2009
#  AA Vehicle - AA Thapsi             93.9 21.1 15 4.455   0.0050
#  AA Vehicle - CC Thapsi            108.8 31.6 15 3.441   0.0350
#  AA Vehicle - EIF2B2 Thapsi        164.6 35.8 15 4.605   0.0038
# ...
